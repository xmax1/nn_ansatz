# %%
# %load_ext autoreload
# %autoreload 2
import os 
# os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
# os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION']='.85'
os.environ['CUDA_VISIBLE_DEVICES'] = '5'

# %%
import sys
sys.path.append('/home/amawi/projects/nn_ansatz/src')
from nn_ansatz import *
from jax.experimental.optimizers import adam
from jax import tree_util
from tqdm.notebook import trange
from jax import pmap, vmap, grad

# %%
# using routines
system = ['LiSolidBCC']
lengths = [2., 4., 6.]
orbitals = ['anisotropic',]
scalar_inputs = [False,]
n_ps = [1,]

e_means = []
for orbital in orbitals:
    for l in lengths:
        name = 'cell_extrapolation_%s_l%.2f' % (orbital, l)
        cfg = setup(system=system[0],
                    n_pre_it=0,
                    n_walkers=512,
                    n_layers=3,
                    n_sh=32,
                    step_size=0.02,
                    n_ph=8,
                    scalar_inputs=False,
                    orbitals=orbital,
                    n_periodic_input=1,
                    opt='adam',
                    n_det=4,
                    print_every=100,
                    save_every=2500,
                    lr=1e-4,
                    n_it=5000,
                    name=name)
        cfg['unit_cell_length'] = l
        log = run_vmc(cfg)
        e_mean = log.summary['e_mean_mean']
        e_means.append(e_mean)
# Out:
# s32_p8_l3_det4 adam_1lr-4_1d-3_1nc-4_m512_ cell_extrapolation_anisotropic_l2.00
# version 		 081021
# seed 		 369
# n_devices 		 1
# save_every 		 2500
# print_every 		 100
# exp_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0
# events_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/events
# models_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/models
# opt_state_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/models/opt_state
# pre_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/pretrained/s32_p8_l3_det4_1lr-4_i0.pk
# timing_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/events/timing
# csv_cfg_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/config1.csv
# pk_cfg_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l2.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/config1.pk
# system 		 LiSolidBCC
# r_atoms 		 [[0.  0.  0. ]
#  [0.5 0.5 0.5]]
# z_atoms 		 [3. 3.]
# n_el 		 6
# n_el_atoms 		 [3 3]
# periodic_boundaries 		 True
# real_basis 		 [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# unit_cell_length 		 6.63
# real_cut 		 6
# reciprocal_cut 		 6
# kappa 		 0.5
# n_layers 		 3
# n_sh 		 32
# n_ph 		 8
# n_det 		 4
# scalar_inputs 		 False
# n_periodic_input 		 1
# orbitals 		 anisotropic
# opt 		 adam
# lr 		 0.0001
# damping 		 0.001
# norm_constraint 		 0.0001
# n_it 		 5000
# load_it 		 0
# n_walkers 		 512
# n_walkers_per_device 		 512
# step_size 		 0.02
# correlation_length 		 10
# pre_lr 		 0.0001
# n_pre_it 		 0
# load_pretrain 		 False
# pretrain 		 False
# System:
#  n_atoms = 2
#  n_up    = 3
#  n_down  = 3
#  n_el    = 6
#
# Ansatz:
#  n_layers = 3
#  n_det    = 4
#  n_sh     = 32
#  n_ph     = 8
#
# Cell:
#  real_basis:
#  [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]]
#  reciprocal_basis:
#  [[3.1415927 0.        0.       ]
#  [0.        3.1415927 0.       ]
#  [0.        0.        3.1415927]]
#  real_cut         = 6.00
#  reciprocal_cut   = 6
#  kappa            = 0.50
#  volume           = 8.00
#  min_cell_width   = 2.00
#  n_periodic_input = 1
#  unit_cell_length = 2.00
#
# converged SCF energy = -12.1628037018806
# creating wf
# sampling no infs, this could take a while
# end sampling no infs
# training:   0%|          | 1/5001 [00:00<?, ?it/s]
# step 100 | e_mean -0.1115 | e_std 31.1701 | e_mean_mean 0.0689 | acceptance 0.4820 | t_per_it 0.1213 |
# step 200 | e_mean -1.6929 | e_std 30.7453 | e_mean_mean -1.3651 | acceptance 0.4971 | t_per_it 0.1154 |
# step 300 | e_mean -3.9699 | e_std 27.8106 | e_mean_mean -3.6333 | acceptance 0.4975 | t_per_it 0.1133 |
# step 400 | e_mean -4.3435 | e_std 27.1322 | e_mean_mean -6.5480 | acceptance 0.4984 | t_per_it 0.1127 |
# step 500 | e_mean -8.7811 | e_std 35.7671 | e_mean_mean -7.2536 | acceptance 0.4930 | t_per_it 0.1127 |
# step 600 | e_mean -7.9356 | e_std 25.8398 | e_mean_mean -8.2551 | acceptance 0.4965 | t_per_it 0.1125 |
# step 700 | e_mean -11.6636 | e_std 29.4828 | e_mean_mean -10.3974 | acceptance 0.4988 | t_per_it 0.1126 |
# step 800 | e_mean -12.8728 | e_std 25.8718 | e_mean_mean -12.3782 | acceptance 0.5047 | t_per_it 0.1125 |
# step 900 | e_mean -12.8156 | e_std 25.3669 | e_mean_mean -13.5498 | acceptance 0.4799 | t_per_it 0.1126 |
# step 1000 | e_mean -15.0332 | e_std 23.0004 | e_mean_mean -14.3761 | acceptance 0.5092 | t_per_it 0.1127 |
# step 1100 | e_mean -13.4172 | e_std 23.0672 | e_mean_mean -15.1622 | acceptance 0.4945 | t_per_it 0.1130 |
# step 1200 | e_mean -13.6142 | e_std 28.4731 | e_mean_mean -15.0655 | acceptance 0.5014 | t_per_it 0.1130 |
# step 1300 | e_mean -17.5283 | e_std 30.7633 | e_mean_mean -15.3920 | acceptance 0.4975 | t_per_it 0.1129 |
# step 1400 | e_mean -17.1187 | e_std 25.3920 | e_mean_mean -16.3135 | acceptance 0.5000 | t_per_it 0.1128 |
# step 1500 | e_mean -20.7551 | e_std 83.7167 | e_mean_mean -16.9236 | acceptance 0.5037 | t_per_it 0.1128 |
# step 1600 | e_mean -18.8485 | e_std 22.6094 | e_mean_mean -17.6295 | acceptance 0.4873 | t_per_it 0.1129 |
# step 1700 | e_mean -20.1162 | e_std 23.5348 | e_mean_mean -18.5492 | acceptance 0.4980 | t_per_it 0.1129 |
# step 1800 | e_mean -19.5704 | e_std 24.3948 | e_mean_mean -19.3962 | acceptance 0.5061 | t_per_it 0.1129 |
# step 1900 | e_mean -23.6603 | e_std 24.7635 | e_mean_mean -20.6305 | acceptance 0.4930 | t_per_it 0.1129 |
# step 2000 | e_mean -24.8003 | e_std 33.7144 | e_mean_mean -22.2110 | acceptance 0.4979 | t_per_it 0.1129 |
# step 2100 | e_mean -25.0040 | e_std 24.6036 | e_mean_mean -23.9243 | acceptance 0.5020 | t_per_it 0.1129 |
# step 2200 | e_mean -27.9957 | e_std 24.0882 | e_mean_mean -25.6385 | acceptance 0.4861 | t_per_it 0.1128 |
# step 2300 | e_mean -31.0840 | e_std 23.0954 | e_mean_mean -27.8652 | acceptance 0.4988 | t_per_it 0.1129 |
# step 2400 | e_mean -33.2445 | e_std 26.2385 | e_mean_mean -30.5332 | acceptance 0.4801 | t_per_it 0.1129 |
# step 2500 | e_mean -35.9165 | e_std 23.1282 | e_mean_mean -32.7551 | acceptance 0.4836 | t_per_it 0.1129 |
# step 2600 | e_mean -37.5132 | e_std 23.3235 | e_mean_mean -34.8485 | acceptance 0.5127 | t_per_it 0.1129 |
# step 2700 | e_mean -40.4489 | e_std 30.7504 | e_mean_mean -36.5356 | acceptance 0.4875 | t_per_it 0.1130 |
# step 2800 | e_mean -38.5616 | e_std 23.1157 | e_mean_mean -37.8814 | acceptance 0.4850 | t_per_it 0.1129 |
# step 2900 | e_mean -41.2857 | e_std 27.1371 | e_mean_mean -38.8815 | acceptance 0.5129 | t_per_it 0.1129 |
# step 3000 | e_mean -41.9961 | e_std 23.3483 | e_mean_mean -39.5165 | acceptance 0.5174 | t_per_it 0.1130 |
# step 3100 | e_mean -41.0288 | e_std 22.7920 | e_mean_mean -40.5420 | acceptance 0.5125 | t_per_it 0.1129 |
# step 3200 | e_mean -41.6109 | e_std 24.6014 | e_mean_mean -41.2721 | acceptance 0.5084 | t_per_it 0.1129 |
# step 3300 | e_mean -40.8451 | e_std 23.6454 | e_mean_mean -41.7568 | acceptance 0.5004 | t_per_it 0.1128 |
# step 3400 | e_mean -41.9015 | e_std 19.8867 | e_mean_mean -42.4799 | acceptance 0.4977 | t_per_it 0.1127 |
# step 3500 | e_mean -43.8111 | e_std 22.6761 | e_mean_mean -43.0153 | acceptance 0.5105 | t_per_it 0.1127 |
# step 3600 | e_mean -43.8445 | e_std 22.9071 | e_mean_mean -43.5165 | acceptance 0.5076 | t_per_it 0.1126 |
# step 3700 | e_mean -42.6826 | e_std 23.8121 | e_mean_mean -44.1945 | acceptance 0.5078 | t_per_it 0.1126 |
# step 3800 | e_mean -44.6060 | e_std 28.1782 | e_mean_mean -44.4555 | acceptance 0.5184 | t_per_it 0.1127 |
# step 3900 | e_mean -43.8317 | e_std 25.7067 | e_mean_mean -44.6448 | acceptance 0.5057 | t_per_it 0.1128 |
# step 4000 | e_mean -48.8721 | e_std 27.6683 | e_mean_mean -44.8992 | acceptance 0.4971 | t_per_it 0.1128 |
# step 4100 | e_mean -46.3297 | e_std 30.4321 | e_mean_mean -44.9867 | acceptance 0.5035 | t_per_it 0.1129 |
# step 4200 | e_mean -43.3742 | e_std 24.2715 | e_mean_mean -45.3427 | acceptance 0.4986 | t_per_it 0.1128 |
# step 4300 | e_mean -46.9149 | e_std 24.8800 | e_mean_mean -45.7881 | acceptance 0.4982 | t_per_it 0.1128 |
# step 4400 | e_mean -46.6053 | e_std 22.5368 | e_mean_mean -45.8549 | acceptance 0.5033 | t_per_it 0.1128 |
# step 4500 | e_mean -45.5570 | e_std 22.1216 | e_mean_mean -45.7424 | acceptance 0.4982 | t_per_it 0.1127 |
# step 4600 | e_mean -44.3236 | e_std 21.6627 | e_mean_mean -45.9330 | acceptance 0.4945 | t_per_it 0.1127 |
# step 4700 | e_mean -46.3625 | e_std 21.0691 | e_mean_mean -46.0781 | acceptance 0.4869 | t_per_it 0.1127 |
# step 4800 | e_mean -50.9540 | e_std 30.2584 | e_mean_mean -46.0954 | acceptance 0.4975 | t_per_it 0.1126 |
# step 4900 | e_mean -44.9708 | e_std 27.4843 | e_mean_mean -46.8185 | acceptance 0.4998 | t_per_it 0.1126 |
# step 5000 | e_mean -48.3477 | e_std 23.9611 | e_mean_mean -47.9196 | acceptance 0.5035 | t_per_it 0.1125 |
# s32_p8_l3_det4 adam_1lr-4_1d-3_1nc-4_m512_ cell_extrapolation_anisotropic_l4.00
# version 		 081021
# seed 		 369
# n_devices 		 1
# save_every 		 2500
# print_every 		 100
# exp_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0
# events_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/events
# models_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/models
# opt_state_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/models/opt_state
# pre_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/pretrained/s32_p8_l3_det4_1lr-4_i0.pk
# timing_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/events/timing
# csv_cfg_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/config1.csv
# pk_cfg_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l4.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/config1.pk
# system 		 LiSolidBCC
# r_atoms 		 [[0.  0.  0. ]
#  [0.5 0.5 0.5]]
# z_atoms 		 [3. 3.]
# n_el 		 6
# n_el_atoms 		 [3 3]
# periodic_boundaries 		 True
# real_basis 		 [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# unit_cell_length 		 6.63
# real_cut 		 6
# reciprocal_cut 		 6
# kappa 		 0.5
# n_layers 		 3
# n_sh 		 32
# n_ph 		 8
# n_det 		 4
# scalar_inputs 		 False
# n_periodic_input 		 1
# orbitals 		 anisotropic
# opt 		 adam
# lr 		 0.0001
# damping 		 0.001
# norm_constraint 		 0.0001
# n_it 		 5000
# load_it 		 0
# n_walkers 		 512
# n_walkers_per_device 		 512
# step_size 		 0.02
# correlation_length 		 10
# pre_lr 		 0.0001
# n_pre_it 		 0
# load_pretrain 		 False
# pretrain 		 False
# System:
#  n_atoms = 2
#  n_up    = 3
#  n_down  = 3
#  n_el    = 6
#
# Ansatz:
#  n_layers = 3
#  n_det    = 4
#  n_sh     = 32
#  n_ph     = 8
#
# Cell:
#  real_basis:
#  [[4. 0. 0.]
#  [0. 4. 0.]
#  [0. 0. 4.]]
#  reciprocal_basis:
#  [[1.5707964 0.        0.       ]
#  [0.        1.5707964 0.       ]
#  [0.        0.        1.5707964]]
#  real_cut         = 6.00
#  reciprocal_cut   = 6
#  kappa            = 0.50
#  volume           = 64.00
#  min_cell_width   = 4.00
#  n_periodic_input = 1
#  unit_cell_length = 4.00
#
# converged SCF energy = -12.1628037018806
# creating wf
# sampling no infs, this could take a while
# end sampling no infs
# training:   0%|          | 1/5001 [00:00<?, ?it/s]
# step 100 | e_mean -8.9554 | e_std 7.0549 | e_mean_mean -9.3688 | acceptance 0.5465 | t_per_it 0.0934 |
# step 200 | e_mean -11.0472 | e_std 7.6188 | e_mean_mean -11.1841 | acceptance 0.5082 | t_per_it 0.0945 |
# step 300 | e_mean -12.2624 | e_std 7.6659 | e_mean_mean -12.2992 | acceptance 0.4891 | t_per_it 0.0941 |
# step 400 | e_mean -14.7249 | e_std 7.5964 | e_mean_mean -13.8626 | acceptance 0.5121 | t_per_it 0.0943 |
# step 500 | e_mean -14.2982 | e_std 6.2076 | e_mean_mean -14.5009 | acceptance 0.5111 | t_per_it 0.0942 |
# step 600 | e_mean -14.1819 | e_std 5.3248 | e_mean_mean -14.9278 | acceptance 0.4965 | t_per_it 0.0942 |
# step 700 | e_mean -15.3233 | e_std 5.9648 | e_mean_mean -15.3348 | acceptance 0.5008 | t_per_it 0.0945 |
# step 800 | e_mean -15.1676 | e_std 6.1205 | e_mean_mean -15.4401 | acceptance 0.4965 | t_per_it 0.0945 |
# step 900 | e_mean -15.4542 | e_std 6.3255 | e_mean_mean -15.7748 | acceptance 0.4893 | t_per_it 0.0942 |
# step 1000 | e_mean -16.3354 | e_std 5.9726 | e_mean_mean -15.9854 | acceptance 0.5053 | t_per_it 0.0940 |
# step 1100 | e_mean -16.4531 | e_std 6.4321 | e_mean_mean -16.3313 | acceptance 0.5074 | t_per_it 0.0939 |
# step 1200 | e_mean -16.7279 | e_std 6.3161 | e_mean_mean -16.5580 | acceptance 0.4971 | t_per_it 0.0938 |
# step 1300 | e_mean -16.5868 | e_std 5.4056 | e_mean_mean -16.8037 | acceptance 0.4947 | t_per_it 0.0937 |
# step 1400 | e_mean -17.0802 | e_std 6.6061 | e_mean_mean -16.9265 | acceptance 0.4990 | t_per_it 0.0936 |
# step 1500 | e_mean -17.9189 | e_std 6.2209 | e_mean_mean -17.2116 | acceptance 0.4885 | t_per_it 0.0937 |
# step 1600 | e_mean -17.3350 | e_std 4.5229 | e_mean_mean -17.4286 | acceptance 0.4996 | t_per_it 0.0937 |
# step 1700 | e_mean -17.6013 | e_std 4.7612 | e_mean_mean -17.6191 | acceptance 0.5148 | t_per_it 0.0937 |
# step 1800 | e_mean -18.7559 | e_std 7.1035 | e_mean_mean -17.8281 | acceptance 0.4996 | t_per_it 0.0938 |
# step 1900 | e_mean -18.4237 | e_std 7.4912 | e_mean_mean -18.0191 | acceptance 0.5008 | t_per_it 0.0940 |
# step 2000 | e_mean -18.0435 | e_std 4.4715 | e_mean_mean -18.1477 | acceptance 0.4830 | t_per_it 0.0940 |
# step 2100 | e_mean -19.2772 | e_std 11.7885 | e_mean_mean -18.2235 | acceptance 0.5107 | t_per_it 0.0942 |
# step 2200 | e_mean -18.8360 | e_std 7.7810 | e_mean_mean -18.3356 | acceptance 0.4967 | t_per_it 0.0942 |
# step 2300 | e_mean -18.3083 | e_std 4.7810 | e_mean_mean -18.4747 | acceptance 0.4893 | t_per_it 0.0941 |
# step 2400 | e_mean -18.8117 | e_std 5.4169 | e_mean_mean -18.6528 | acceptance 0.4873 | t_per_it 0.0942 |
# step 2500 | e_mean -18.8851 | e_std 5.1102 | e_mean_mean -18.7017 | acceptance 0.4914 | t_per_it 0.0942 |
# step 2600 | e_mean -18.9535 | e_std 6.4690 | e_mean_mean -18.7966 | acceptance 0.5063 | t_per_it 0.0942 |
# step 2700 | e_mean -19.1839 | e_std 5.8587 | e_mean_mean -18.8249 | acceptance 0.4869 | t_per_it 0.0942 |
# step 2800 | e_mean -19.7845 | e_std 10.5018 | e_mean_mean -18.9205 | acceptance 0.5053 | t_per_it 0.0942 |
# step 2900 | e_mean -18.6175 | e_std 4.2866 | e_mean_mean -18.9591 | acceptance 0.5039 | t_per_it 0.0943 |
# step 3000 | e_mean -19.5968 | e_std 7.1029 | e_mean_mean -18.9526 | acceptance 0.5125 | t_per_it 0.0943 |
# step 3100 | e_mean -19.0957 | e_std 4.3669 | e_mean_mean -18.8711 | acceptance 0.5006 | t_per_it 0.0943 |
# step 3200 | e_mean -18.9327 | e_std 4.6572 | e_mean_mean -18.9503 | acceptance 0.5008 | t_per_it 0.0942 |
# step 3300 | e_mean -19.4870 | e_std 5.1510 | e_mean_mean -18.9998 | acceptance 0.5033 | t_per_it 0.0942 |
# step 3400 | e_mean -19.1627 | e_std 5.7405 | e_mean_mean -19.0910 | acceptance 0.4953 | t_per_it 0.0942 |
# step 3500 | e_mean -18.9445 | e_std 6.0705 | e_mean_mean -19.0998 | acceptance 0.4939 | t_per_it 0.0942 |
# step 3600 | e_mean -18.7945 | e_std 5.0833 | e_mean_mean -19.0419 | acceptance 0.4967 | t_per_it 0.0942 |
# step 3700 | e_mean -19.8248 | e_std 8.1630 | e_mean_mean -19.0337 | acceptance 0.5072 | t_per_it 0.0942 |
# step 3800 | e_mean -19.0575 | e_std 4.9951 | e_mean_mean -19.0141 | acceptance 0.4982 | t_per_it 0.0943 |
# step 3900 | e_mean -18.8291 | e_std 4.1086 | e_mean_mean -19.0174 | acceptance 0.4906 | t_per_it 0.0943 |
# step 4000 | e_mean -19.0627 | e_std 5.2159 | e_mean_mean -19.0225 | acceptance 0.5111 | t_per_it 0.0943 |
# step 4100 | e_mean -18.5492 | e_std 5.1388 | e_mean_mean -18.9810 | acceptance 0.5252 | t_per_it 0.0942 |
# step 4200 | e_mean -18.9370 | e_std 4.4498 | e_mean_mean -18.8932 | acceptance 0.4973 | t_per_it 0.0942 |
# step 4300 | e_mean -18.7850 | e_std 4.4285 | e_mean_mean -18.7440 | acceptance 0.5127 | t_per_it 0.0941 |
# step 4400 | e_mean -18.6283 | e_std 5.3054 | e_mean_mean -18.6974 | acceptance 0.5027 | t_per_it 0.0941 |
# step 4500 | e_mean -18.8543 | e_std 5.3507 | e_mean_mean -18.6633 | acceptance 0.4936 | t_per_it 0.0941 |
# step 4600 | e_mean -19.4510 | e_std 5.0605 | e_mean_mean -18.6219 | acceptance 0.4943 | t_per_it 0.0941 |
# step 4700 | e_mean -18.7831 | e_std 5.2791 | e_mean_mean -18.6790 | acceptance 0.5035 | t_per_it 0.0941 |
# step 4800 | e_mean -18.4257 | e_std 17.1175 | e_mean_mean -18.6196 | acceptance 0.5057 | t_per_it 0.0941 |
# step 4900 | e_mean -18.0701 | e_std 4.2809 | e_mean_mean -18.5472 | acceptance 0.4900 | t_per_it 0.0941 |
# step 5000 | e_mean -17.6692 | e_std 3.8996 | e_mean_mean -18.4258 | acceptance 0.4975 | t_per_it 0.0941 |
# s32_p8_l3_det4 adam_1lr-4_1d-3_1nc-4_m512_ cell_extrapolation_anisotropic_l6.00
# version 		 081021
# seed 		 369
# n_devices 		 1
# save_every 		 2500
# print_every 		 100
# exp_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0
# events_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/events
# models_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/models
# opt_state_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/models/opt_state
# pre_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/pretrained/s32_p8_l3_det4_1lr-4_i0.pk
# timing_dir 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/events/timing
# csv_cfg_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/config1.csv
# pk_cfg_path 		 /home/amawi/projects/nn_ansatz/src/demos/move_atom_positions/lithium_increaseing_cell_size/experiments/LiSolidBCC/081021/cell_extrapolation_anisotropic_l6.00/adam_1lr-4_1d-3_1nc-4_m512_s32_p8_l3_det4/run0/config1.pk
# system 		 LiSolidBCC
# r_atoms 		 [[0.  0.  0. ]
#  [0.5 0.5 0.5]]
# z_atoms 		 [3. 3.]
# n_el 		 6
# n_el_atoms 		 [3 3]
# periodic_boundaries 		 True
# real_basis 		 [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# unit_cell_length 		 6.63
# real_cut 		 6
# reciprocal_cut 		 6
# kappa 		 0.5
# n_layers 		 3
# n_sh 		 32
# n_ph 		 8
# n_det 		 4
# scalar_inputs 		 False
# n_periodic_input 		 1
# orbitals 		 anisotropic
# opt 		 adam
# lr 		 0.0001
# damping 		 0.001
# norm_constraint 		 0.0001
# n_it 		 5000
# load_it 		 0
# n_walkers 		 512
# n_walkers_per_device 		 512
# step_size 		 0.02
# correlation_length 		 10
# pre_lr 		 0.0001
# n_pre_it 		 0
# load_pretrain 		 False
# pretrain 		 False
# System:
#  n_atoms = 2
#  n_up    = 3
#  n_down  = 3
#  n_el    = 6
#
# Ansatz:
#  n_layers = 3
#  n_det    = 4
#  n_sh     = 32
#  n_ph     = 8
#
# Cell:
#  real_basis:
#  [[6. 0. 0.]
#  [0. 6. 0.]
#  [0. 0. 6.]]
#  reciprocal_basis:
#  [[1.0471976 0.        0.       ]
#  [0.        1.0471976 0.       ]
#  [0.        0.        1.0471976]]
#  real_cut         = 6.00
#  reciprocal_cut   = 6
#  kappa            = 0.50
#  volume           = 216.00
#  min_cell_width   = 6.00
#  n_periodic_input = 1
#  unit_cell_length = 6.00
#
# converged SCF energy = -12.1628037018806
# creating wf
# sampling no infs, this could take a while
# end sampling no infs
# training:   0%|          | 1/5001 [00:00<?, ?it/s]
# step 100 | e_mean -11.3040 | e_std 5.8444 | e_mean_mean -10.9137 | acceptance 0.6188 | t_per_it 0.0855 |
# step 200 | e_mean -11.9448 | e_std 5.0087 | e_mean_mean -12.0659 | acceptance 0.4932 | t_per_it 0.0864 |
# step 300 | e_mean -12.4916 | e_std 4.8253 | e_mean_mean -12.4485 | acceptance 0.4936 | t_per_it 0.0867 |
# step 400 | e_mean -12.7774 | e_std 5.1869 | e_mean_mean -12.6908 | acceptance 0.4963 | t_per_it 0.0869 |
# step 500 | e_mean -12.7115 | e_std 3.7776 | e_mean_mean -13.0731 | acceptance 0.5102 | t_per_it 0.0876 |
# step 600 | e_mean -13.3750 | e_std 4.3757 | e_mean_mean -13.2498 | acceptance 0.5025 | t_per_it 0.0878 |
# step 700 | e_mean -13.6874 | e_std 4.2601 | e_mean_mean -13.6487 | acceptance 0.5039 | t_per_it 0.0878 |
# step 800 | e_mean -14.0991 | e_std 4.3341 | e_mean_mean -13.9315 | acceptance 0.4986 | t_per_it 0.0878 |
# step 900 | e_mean -14.3037 | e_std 4.2015 | e_mean_mean -14.1155 | acceptance 0.4980 | t_per_it 0.0878 |
# step 1000 | e_mean -14.7858 | e_std 4.4495 | e_mean_mean -14.5188 | acceptance 0.5057 | t_per_it 0.0879 |
# step 1100 | e_mean -15.0308 | e_std 4.7048 | e_mean_mean -14.6484 | acceptance 0.4908 | t_per_it 0.0879 |
# step 1200 | e_mean -14.8466 | e_std 4.5410 | e_mean_mean -14.7883 | acceptance 0.4990 | t_per_it 0.0880 |
# step 1300 | e_mean -15.3023 | e_std 5.2341 | e_mean_mean -14.9531 | acceptance 0.4877 | t_per_it 0.0880 |
# step 1400 | e_mean -15.2560 | e_std 4.1337 | e_mean_mean -15.1851 | acceptance 0.4979 | t_per_it 0.0880 |
# step 1500 | e_mean -15.4044 | e_std 3.7647 | e_mean_mean -15.3036 | acceptance 0.4893 | t_per_it 0.0882 |
# step 1600 | e_mean -15.3790 | e_std 3.6620 | e_mean_mean -15.3374 | acceptance 0.5027 | t_per_it 0.0883 |
# step 1700 | e_mean -15.6012 | e_std 3.9914 | e_mean_mean -15.4521 | acceptance 0.4932 | t_per_it 0.0883 |
# step 1800 | e_mean -15.4138 | e_std 3.1257 | e_mean_mean -15.6480 | acceptance 0.5172 | t_per_it 0.0883 |
# step 1900 | e_mean -15.7084 | e_std 2.6913 | e_mean_mean -15.7425 | acceptance 0.4932 | t_per_it 0.0883 |
# step 2000 | e_mean -15.8318 | e_std 5.8903 | e_mean_mean -15.8010 | acceptance 0.4928 | t_per_it 0.0883 |
# step 2100 | e_mean -15.7046 | e_std 3.6903 | e_mean_mean -15.8130 | acceptance 0.5039 | t_per_it 0.0883 |
# step 2200 | e_mean -15.8479 | e_std 2.8135 | e_mean_mean -15.8399 | acceptance 0.4996 | t_per_it 0.0884 |
# step 2300 | e_mean -16.0229 | e_std 3.5907 | e_mean_mean -15.8560 | acceptance 0.5010 | t_per_it 0.0885 |
# step 2400 | e_mean -16.0481 | e_std 2.9878 | e_mean_mean -15.8346 | acceptance 0.4805 | t_per_it 0.0885 |
# step 2500 | e_mean -15.8074 | e_std 2.9456 | e_mean_mean -15.8480 | acceptance 0.4896 | t_per_it 0.0885 |
# step 2600 | e_mean -16.1712 | e_std 12.6385 | e_mean_mean -15.8195 | acceptance 0.5092 | t_per_it 0.0884 |
# step 2700 | e_mean -16.3326 | e_std 5.0460 | e_mean_mean -15.7580 | acceptance 0.4936 | t_per_it 0.0884 |
# step 2800 | e_mean -15.7874 | e_std 3.1484 | e_mean_mean -15.7454 | acceptance 0.4900 | t_per_it 0.0884 |
# step 2900 | e_mean -16.0718 | e_std 5.0247 | e_mean_mean -15.8191 | acceptance 0.5018 | t_per_it 0.0884 |
# step 3000 | e_mean -16.0611 | e_std 3.4549 | e_mean_mean -15.9396 | acceptance 0.5199 | t_per_it 0.0884 |
# step 3100 | e_mean -15.8251 | e_std 2.8877 | e_mean_mean -16.0111 | acceptance 0.4979 | t_per_it 0.0884 |
# step 3200 | e_mean -15.6784 | e_std 2.8682 | e_mean_mean -15.9917 | acceptance 0.5041 | t_per_it 0.0885 |
# step 3300 | e_mean -16.0632 | e_std 2.4700 | e_mean_mean -15.9873 | acceptance 0.5191 | t_per_it 0.0885 |
# step 3400 | e_mean -15.9385 | e_std 2.5643 | e_mean_mean -15.9961 | acceptance 0.4986 | t_per_it 0.0885 |
# step 3500 | e_mean -16.1339 | e_std 2.7182 | e_mean_mean -16.0447 | acceptance 0.4979 | t_per_it 0.0885 |
# step 3600 | e_mean -16.0929 | e_std 2.6139 | e_mean_mean -16.1150 | acceptance 0.5102 | t_per_it 0.0885 |
# step 3700 | e_mean -16.1772 | e_std 3.1907 | e_mean_mean -16.0969 | acceptance 0.4986 | t_per_it 0.0885 |
# step 3800 | e_mean -15.9624 | e_std 2.2107 | e_mean_mean -16.1371 | acceptance 0.4957 | t_per_it 0.0885 |
# step 3900 | e_mean -16.1770 | e_std 2.7930 | e_mean_mean -16.1580 | acceptance 0.4990 | t_per_it 0.0886 |
# step 4000 | e_mean -16.2220 | e_std 2.5356 | e_mean_mean -16.1712 | acceptance 0.5039 | t_per_it 0.0886 |
# step 4100 | e_mean -16.3984 | e_std 3.0341 | e_mean_mean -16.2114 | acceptance 0.5064 | t_per_it 0.0886 |
# step 4200 | e_mean -15.9513 | e_std 1.8514 | e_mean_mean -16.2080 | acceptance 0.4963 | t_per_it 0.0886 |
# step 4300 | e_mean -16.0649 | e_std 2.4515 | e_mean_mean -16.1832 | acceptance 0.4930 | t_per_it 0.0886 |
# step 4400 | e_mean -16.1482 | e_std 2.1841 | e_mean_mean -16.1866 | acceptance 0.4836 | t_per_it 0.0886 |
# step 4500 | e_mean -16.0802 | e_std 3.3605 | e_mean_mean -16.1416 | acceptance 0.5037 | t_per_it 0.0886 |
# step 4600 | e_mean -16.1194 | e_std 1.8731 | e_mean_mean -16.1156 | acceptance 0.4938 | t_per_it 0.0886 |
# step 4700 | e_mean -15.8234 | e_std 2.6840 | e_mean_mean -16.0539 | acceptance 0.4854 | t_per_it 0.0887 |
# step 4800 | e_mean -16.1581 | e_std 2.4428 | e_mean_mean -16.0226 | acceptance 0.5039 | t_per_it 0.0887 |
# step 4900 | e_mean -15.8747 | e_std 2.1717 | e_mean_mean -15.9437 | acceptance 0.4775 | t_per_it 0.0887 |
# step 5000 | e_mean -15.8524 | e_std 2.3817 | e_mean_mean -15.8944 | acceptance 0.4896 | t_per_it 0.0887 |

# %%
import matplotlib.pyplot as plt
# 2 3 4 5 10
[-17.98956299, -18.72672653]

ev = 27.2113245
gpaw_means = [(x -77.136551) / ev for x in gpaw_means]
lengths = [2., 4., 6., 10., 12.]
plt.plot(lengths, e_means)
# plt.plot(gpaw_lengths, gpaw_means)
print(e_means)
plt.show()
# Out:
# [array(0.45078853), array(-2.05238247), array(-2.6465919), array(-2.81724381), array(-2.900424)]

# %%
log = run_vmc(config)
# save_pk(log.params, 'params.pk')
# Out:
# System:
#  n_atoms = 2
#  n_up    = 3
#  n_down  = 3
#  n_el    = 6
#
# Ansatz:
#  n_layers = 3
#  n_det    = 4
#  n_sh     = 64
#  n_ph     = 16
#
# Cell:
#  real_basis:
#  [[6.63 0.   0.  ]
#  [0.   6.63 0.  ]
#  [0.   0.   6.63]]
#  reciprocal_basis:
#  [[0.94769007 0.         0.        ]
#  [0.         0.94769007 0.        ]
#  [0.         0.         0.94769007]]
#  real_cut         = 6.00
#  reciprocal_cut   = 6
#  kappa            = 0.50
#  volume           = 291.43
#  min_cell_width   = 6.63
#  n_periodic_input = 1
#  unit_cell_length = 6.63
#
# converged SCF energy = -12.1628037018806
# creating wf
# sampling no infs, this could take a while
# end sampling no infs
# training:   0%|          | 1/7501 [00:00<?, ?it/s]
# step 100 | e_mean -9.1831 | e_std 3.3782 | e_mean_mean -9.1150 | acceptance 0.5057 | t_per_it 0.0684 |
# step 200 | e_mean -9.6069 | e_std 3.0851 | e_mean_mean -9.4766 | acceptance 0.4895 | t_per_it 0.0685 |
# step 300 | e_mean -9.8351 | e_std 2.9581 | e_mean_mean -9.9441 | acceptance 0.5074 | t_per_it 0.0689 |
# step 400 | e_mean -10.2764 | e_std 3.1788 | e_mean_mean -10.1491 | acceptance 0.5111 | t_per_it 0.0688 |
# step 500 | e_mean -10.8160 | e_std 3.1381 | e_mean_mean -10.5383 | acceptance 0.5025 | t_per_it 0.0687 |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8c7d99d31623> in <module>
# ----> 1 log = run_vmc(config)
#       2 # save_pk(log.params, 'params.pk')
#
# ~/projects/nn_ansatz/src/nn_ansatz/routines.py in run_vmc(cfg, walkers)
#      68         # stop = capture_nan(walkers, 'walkers', False)
#      69
# ---> 70         grads, e_locs = grad_fn(params, walkers)
#      71         # stop = capture_nan(grads, 'e_locs', stop)
#      72         # stop = capture_nan(grads, 'grads', stop)
#
# ~/.conda/envs/xmax/lib/python3.7/site-packages/jax/_src/tree_util.py in <lambda>(keys, values)
#     247   collections.OrderedDict,
#     248   lambda x: (list(x.values()), list(x.keys())),
# --> 249   lambda keys, values: collections.OrderedDict(safe_zip(keys, values)))
#     250
#     251 register_pytree_node(
#
# KeyboardInterrupt:

# %%
walkers = None
logger = Logging(**cfg)

keys = rnd.PRNGKey(cfg['seed'])
if bool(os.environ.get('DISTRIBUTE')) is True:
    keys = rnd.split(keys, cfg['n_devices']).reshape(cfg['n_devices'], 2)

mol = SystemAnsatz(**cfg)

vwf = create_wf(mol)
params = initialise_params(mol, keys)
pwf = pmap(create_wf(mol), in_axes=(None, 0))
pwf_grad = grad(lambda x, y: pwf(x, y).sum(), argnums=(0,1))

sampler = create_sampler(mol, vwf)

if cfg['load_pretrain']:
    params, walkers = load_pk(cfg['pre_path'])
elif cfg['pretrain']:
    params, walkers = pretrain_wf(mol, **cfg)

if walkers is None:
    walkers = initialise_walkers(mol, vwf, sampler, params, keys, walkers=walkers)

grad_fn = create_grad_function(mol, vwf)

if cfg['opt'] == 'kfac':
    update, get_params, kfac_update, state = kfac(mol, params, walkers, cfg['lr'], cfg['damping'], cfg['norm_constraint'])
elif cfg['opt'] == 'adam':
    init, update, get_params = adam(cfg['lr'])
    update = jit(update)
    state = init(params)
else:
    exit('Optimiser not available')

steps = trange(1, cfg['n_it']+1, initial=1, total=cfg['n_it']+1, desc='training', disable=None)
step_size = split_variables_for_pmap(cfg['n_devices'], cfg['step_size'])

ke = pmap(create_local_kinetic_energy(vwf), in_axes=(None, 0))
pe = pmap(create_potential_energy(mol), in_axes=(0, None, None))
pmap_compute_ae_vectors_periodic_i = lambda x, y: compute_ae_vectors_periodic_i(x, y, mol.unit_cell_length)
pmap_compute_ae_vectors_periodic_i = pmap(vmap(pmap_compute_ae_vectors_periodic_i, in_axes=(0, None)), in_axes=(0, None))
pmap_compute_ee_vectors_i = pmap(vmap(compute_ee_vectors_i, in_axes=(0,)), in_axes=(0,))
# Out:
# System:
#  n_atoms = 2
#  n_up    = 3
#  n_down  = 3
#  n_el    = 6
#
# Ansatz:
#  n_layers = 2
#  n_det    = 2
#  n_sh     = 32
#  n_ph     = 8
#
# Cell:
#  real_basis:
#  [[6.63 0.   0.  ]
#  [0.   6.63 0.  ]
#  [0.   0.   6.63]]
#  reciprocal_basis:
#  [[0.94769007 0.         0.        ]
#  [0.         0.94769007 0.        ]
#  [0.         0.         0.94769007]]
#  real_cut         = 6.00
#  reciprocal_cut   = 6
#  kappa            = 0.50
#  volume           = 291.43
#  min_cell_width   = 6.63
#  n_periodic_input = 3
#  unit_cell_length = 6.63
#
# converged SCF energy = -12.1628037018806
# creating wf
# creating wf
# sampling no infs, this could take a while
# end sampling no infs
# training:   0%|          | 1/5001 [00:00<?, ?it/s]

# %%
for step in steps:
    keys, subkeys = key_gen(keys)

    walkers, acceptance, step_size = sampler(params, walkers, subkeys, step_size)

    gparam, gwalker = pwf_grad(params, walkers)
    # gparam_nan, gwalker_nan = check_if_nan(gparam, 'x'), check_if_nan(gwalker, 'x')

    pote = pe(walkers, mol.r_atoms, mol.z_atoms)
    pote_nan = check_if_nan(pote, 'x')

    kine = ke(params, walkers)
    kine_nan = check_if_nan(kine,'x')

    ae_vectors = pmap_compute_ae_vectors_periodic_i(walkers, mol.r_atoms)
    ee_vectors = pmap_compute_ee_vectors_i(walkers)
    min_im_ee_vectors = apply_minimum_image_convention(ee_vectors, mol.unit_cell_length)
    min_im_ae_vectors = apply_minimum_image_convention(ae_vectors, mol.unit_cell_length)

    if kine_nan:
        print('nan in kinetic')
        break

    grads, e_locs = grad_fn(params, walkers)

    if cfg['opt'] == 'kfac':
        grads, state = kfac_update(step, grads, state, walkers)

    state = update(step, grads, state)
    params = get_params(state)
    # stop = capture_nan(params, 'params', stop)

    steps.set_postfix(E=f'{jnp.mean(e_locs):.6f}')
    steps.refresh()

    logger.log(step,
                opt_state=state,
                params=params,
                e_locs=e_locs,
                acceptance=acceptance[0])

    # if stop:
        # exit()

logger.walkers = walkers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-73b4cca69023> in <module>
#       5
#       6     gparam, gwalker = pwf_grad(params, walkers)
# ----> 7     gparam_nan, gwalker_nan = check_if_nan(gparam, 'x'), check_if_nan(gwalker, 'x')
#       8
#       9     pote = pe(walkers, mol.r_atoms, mol.z_atoms)
#
# ~/projects/nn_ansatz/src/nn_ansatz/utils.py in check_if_nan(tensor, desc)
#     546
#     547 def check_if_nan(tensor, desc):
# --> 548     if jnp.isnan(tensor).any():
#     549         # save_pk(tensor, 'nan_%s.pk' % desc)
#     550         return True
#
# ~/.conda/envs/xmax/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py in isnan(x)
#    2035 @_wraps(np.isnan)
#    2036 def isnan(x):
# -> 2037   _check_arraylike("isnan", x)
#    2038   return lax.ne(x, x)
#    2039
#
# ~/.conda/envs/xmax/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py in _check_arraylike(fun_name, *args)
#     307                     if not _arraylike(arg))
#     308     msg = "{} requires ndarray or scalar arguments, got {} at position {}."
# --> 309     raise TypeError(msg.format(fun_name, type(arg), pos))
#     310
#     311 def _check_no_float0s(fun_name, *args):
#
# TypeError: isnan requires ndarray or scalar arguments, got <class 'collections.OrderedDict'> at position 0.

# %%
# Pretrain

params, walkers = pretrain_wf(params,
                              wf,
                              wf_orbitals,
                              mol,
                              walkers,
                              n_it=n_pre_it,
                              lr=1e-4,
                              n_eq_it=n_pre_it)

# %%
# vmc loop with kfac

grad_fn = create_grad_function(wf, mol)


update, get_params, kfac_update, state = kfac(kfac_wf, wf, mol, params, walkers, d0s,
                                                  lr=lr,
                                                  damping=damping,
                                                  norm_constraint=norm_constraint)


steps = trange(0, n_it, initial=0, total=n_it, desc='training', disable=None)
for step in steps:
    key, subkey = rnd.split(key)

    walkers, acceptance, step_size = sampler(params, walkers, d0s, subkey, step_size)

    grads, e_locs = grad_fn(params, walkers, d0s)

    grads, state = kfac_update(step, grads, state, walkers, d0s)

    state = update(step, grads, state)
    params = get_params(state)

    steps.set_postfix(E=f'{jnp.mean(e_locs):.6f}')
    steps.refresh()
    

print('exit')
# Out:
# exit

# %%
# periodic boundaries test

for (name, method) in zip(('LiSolid'), ('kfac')):
    config = setup(system=name,
                   pretrain=True,
                   n_pre_it=501,
                   n_walkers=2048,
                   n_layers=2,
                   n_sh=64,
                   n_ph=16,
                   opt=method,
                   n_det=8,
                   print_every=100,
                   save_every=5000,
                   lr=1e-4,
                   n_it=10000,
                   norm_constraint=1e-4,
                   damping=1e-3,
                   exp=True)

    run_vmc(**config)
# Out:
# Pretrain path does not exist, can't load
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cf84755c87ae> in <module>
#       2
#       3 for (name, method) in zip(('LiSolid'), ('kfac')):
# ----> 4     config = setup(system=name,
#       5                    pretrain=True,
#       6                    n_pre_it=501,
#
# ~/nn_ansatz/src/nn_ansatz/utils.py in setup(system, name, exp, save_every, print_every, r_atoms, z_atoms, n_el, n_el_atoms, ignore_toml, periodic_boundaries, cell_basis, unit_cell_length, opt, lr, damping, norm_constraint, n_it, n_walkers, step_size, n_layers, n_sh, n_ph, n_det, pre_lr, n_pre_it, pretrain, load_it, load_dir, seed)
#     187
#     188     r_atoms, z_atoms, n_el, n_el_atoms, periodic_boundaries, cell_basis, unit_cell_length \
# --> 189         = get_system(system, r_atoms, z_atoms, n_el, n_el_atoms, periodic_boundaries, cell_basis, unit_cell_length, ignore_toml)
#     190
#     191     config = {'version': version,
#
# ~/nn_ansatz/src/nn_ansatz/utils.py in get_system(system, r_atoms, z_atoms, n_el, n_el_atoms, periodic_boundaries, cell_basis, unit_cell_length, ignore_toml)
#      97                 n_el = 4
#      98             else:
# ---> 99                 exit('Need number of electrons as minimum input or system in toml file')
#     100         print('Assuming atomic system')
#     101         n_el_atoms = jnp.array([n_el]) if n_el is not None else n_el_atoms
#
# NameError: name 'exit' is not defined

# %%
config = setup(system='LiSolid',
               pretrain=True,
               n_pre_it=501,
               n_walkers=2048,
               n_layers=2,
               n_sh=64,
               n_ph=16,
               opt='kfac',
               n_det=8,
               print_every=100,
               save_every=5000,
               lr=1e-3,
               n_it=1000,
               norm_constraint=1e-4,
               damping=1e-3,
               exp=True,
               name='sampler_fix')

run_vmc(**config)
# Out:
# version 		 200421
# seed 		 369
# save_every 		 5000
# print_every 		 100
# exp_dir 		 /home/xmax/projects/nn_ansatz/src/experiments/LiSolid/sampler_fix/kfac_1lr-3_1d-3_1nc-4_m2048_s64_p16_l2_det8/run4
# events_dir 		 /home/xmax/projects/nn_ansatz/src/experiments/LiSolid/sampler_fix/kfac_1lr-3_1d-3_1nc-4_m2048_s64_p16_l2_det8/run4/events
# models_dir 		 /home/xmax/projects/nn_ansatz/src/experiments/LiSolid/sampler_fix/kfac_1lr-3_1d-3_1nc-4_m2048_s64_p16_l2_det8/run4/models
# opt_state_dir 		 /home/xmax/projects/nn_ansatz/src/experiments/LiSolid/sampler_fix/kfac_1lr-3_1d-3_1nc-4_m2048_s64_p16_l2_det8/run4/models/opt_state
# pre_path 		 /home/xmax/projects/nn_ansatz/src/experiments/LiSolid/pretrained/s64_p16_l2_det8_1lr-4_i501.pk
# timing_dir 		 /home/xmax/projects/nn_ansatz/src/experiments/LiSolid/sampler_fix/kfac_1lr-3_1d-3_1nc-4_m2048_s64_p16_l2_det8/run4/events/timing
# system 		 LiSolid
# r_atoms 		 [[0.5 0.5 0.5]]
# z_atoms 		 [3.]
# n_el 		 3
# n_el_atoms 		 [3]
# periodic_boundaries 		 True
# cell_basis 		 [[-0.5  0.5  0.5]
#  [ 0.5 -0.5  0.5]
#  [ 0.5  0.5 -0.5]]
# unit_cell_length 		 7.407726
# n_layers 		 2
# n_sh 		 64
# n_ph 		 16
# n_det 		 8
# opt 		 kfac
# lr 		 0.001
# damping 		 0.001
# norm_constraint 		 0.0001
# n_it 		 1000
# load_it 		 0
# n_walkers 		 2048
# step_size 		 0.02
# pre_lr 		 0.0001
# n_pre_it 		 501
# load_pretrain 		 True
# pretrain 		 True
# System:
#  n_atoms = 1
#  n_up    = 2
#  n_down  = 1
#  n_el    = 3
#
# Ansatz:
#  n_layers = 2
#  n_det    = 8
#  n_sh     = 64
#  n_ph     = 16
#
# converged SCF energy = -7.31552598128109
# LENGTH PRIMITIVE CELL 0.8660254
# training:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-3-97c8dff9f13d> in <module>
#      18
# ---> 19 run_vmc(**config)
#
# ~/projects/nn_ansatz/src/nn_ansatz/routines.py in run_vmc(r_atoms, z_atoms, n_el, n_el_atoms, periodic_boundaries, cell_basis, unit_cell_length, opt, lr, damping, norm_constraint, n_it, n_walkers, step_size, n_layers, n_sh, n_ph, n_det, pre_lr, n_pre_it, load_pretrain, pretrain, pre_path, seed, **kwargs)
#     121
# --> 122         grads, e_locs = grad_fn(params, walkers, d0s)
#     123
#
# ~/projects/nn_ansatz/src/nn_ansatz/vmc.py in _grad_function(params, walkers, d0s)
#      32
# ---> 33         e_locs = lax.stop_gradient(compute_energy(params, walkers, d0s))
#      34         e_locs_centered = clip_and_center(e_locs)
#
# ~/projects/nn_ansatz/src/nn_ansatz/vmc.py in _compute_local_energy(params, walkers, d0s)
#      53     def _compute_local_energy(params, walkers, d0s):
# ---> 54         potential_energy = compute_potential_energy(walkers, r_atoms, z_atoms)
#      55         kinetic_energy = local_kinetic_energy(params, walkers, d0s)
#
# ~/projects/nn_ansatz/src/nn_ansatz/vmc.py in compute_potential_energy_solid_i(walkers, r_atoms, z_atoms)
#      97             a_e_dist = batched_cdist_l2(ex_r_atoms, walkers)
# ---> 98             potential_energy -= jnp.sum(ex_z_atoms / a_e_dist)
#      99
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5332       return NotImplemented
# -> 5333     return binary_op(self, other)
#    5334   return deferring_binary_op
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in true_divide(x1, x2)
#     537   x1, x2 = _promote_args_inexact("true_divide", x1, x2)
# --> 538   return lax.div(x1, x2)
#     539
#
# FilteredStackTrace: TypeError: div got incompatible shapes for broadcasting: (2048, 3, 3), (2048, 3, 14).
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-97c8dff9f13d> in <module>
#      17                name='sampler_fix')
#      18
# ---> 19 run_vmc(**config)
#
# ~/projects/nn_ansatz/src/nn_ansatz/routines.py in run_vmc(r_atoms, z_atoms, n_el, n_el_atoms, periodic_boundaries, cell_basis, unit_cell_length, opt, lr, damping, norm_constraint, n_it, n_walkers, step_size, n_layers, n_sh, n_ph, n_det, pre_lr, n_pre_it, load_pretrain, pretrain, pre_path, seed, **kwargs)
#     120         walkers, acceptance, step_size = sampler(params, walkers, d0s, subkey, step_size)
#     121
# --> 122         grads, e_locs = grad_fn(params, walkers, d0s)
#     123
#     124         if opt == 'kfac':
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     380         return cpp_jitted_f(*args, **kwargs)
#     381       else:
# --> 382         return cpp_jitted_f(context, *args, **kwargs)
#     383   else:
#     384     cpp_jitted_f = jax_jit.jit(fun, cache_miss, get_device_info,
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in cache_miss_wrapper(_, *args, **kw)
#     349   # version.
#     350   if lib._xla_extension_version < 11:
# --> 351     def cache_miss_wrapper(_, *args, **kw): return cache_miss(*args, **kw)
#     352     static_argnums_ = (0,) + tuple(i + 1 for i in static_argnums)
#     353     cpp_jitted_f = jax_jit.jit(fun, cache_miss_wrapper, get_device_info,
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in cache_miss(*args, **kwargs)
#     293       _check_arg(arg)
#     294     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 295     out_flat = xla.xla_call(
#     296         flat_fun,
#     297         *args_flat,
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     598
#     599   def process_call(self, primitive, f, tracers, params):
# --> 600     return primitive.impl(f, *tracers, **params)
#     601   process_map = process_call
#     602
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     575
#     576 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
# --> 577   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     578                                *unsafe_map(arg_spec, args))
#     579   try:
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     258       fun.populate_stores(stores)
#     259     else:
# --> 260       ans = call(fun, *args)
#     261       cache[key] = (ans, fun.stores)
#     262
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_callable(fun, device, backend, name, donated_invars, *arg_specs)
#     652   abstract_args, arg_devices = unzip2(arg_specs)
#     653   if config.omnistaging_enabled:
# --> 654     jaxpr, out_avals, consts = pe.trace_to_jaxpr_final(fun, abstract_args)
#     655     if any(isinstance(c, core.Tracer) for c in consts):
#     656       raise core.UnexpectedTracerError("Encountered an unexpected tracer.")
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr_final(fun, in_avals)
#    1226     main.source_info = fun_sourceinfo(fun.f)  # type: ignore
#    1227     main.jaxpr_stack = ()  # type: ignore
# -> 1228     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1229     del fun, main
#    1230   return jaxpr, out_avals, consts
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1206     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1207     in_tracers = map(trace.new_arg, in_avals)
# -> 1208     ans = fun.call_wrapped(*in_tracers)
#    1209     out_tracers = map(trace.full_raise, ans)
#    1210     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in grad_f_aux(*args, **kwargs)
#     756   @api_boundary
#     757   def grad_f_aux(*args, **kwargs):
# --> 758     (_, aux), g = value_and_grad_f(*args, **kwargs)
#     759     return g, aux
#     760
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     815       ans, vjp_py = _vjp(f_partial, *dyn_args)
#     816     else:
# --> 817       ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#     818     _check_scalar(ans)
#     819     dtype = dtypes.result_type(ans)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in _vjp(fun, has_aux, *primals)
#    1890   else:
#    1891     flat_fun, out_aux_trees = flatten_fun_nokwargs2(fun, in_tree)
# -> 1892     out_primal, out_vjp, aux = ad.vjp(flat_fun, primals_flat, has_aux=True)
#    1893     out_tree, aux_tree = out_aux_trees()
#    1894   out_primal_py = tree_unflatten(out_tree, out_primal)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/ad.py in vjp(traceable, primals, has_aux)
#     114     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     115   else:
# --> 116     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#     117
#     118   def unbound_vjp(pvals, jaxpr, consts, *cts):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/ad.py in linearize(traceable, *primals, **kwargs)
#      99   _, in_tree = tree_flatten(((primals, primals), {}))
#     100   jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 101   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(jvpfun_flat, in_pvals)
#     102   out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     103   assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate)
#     508   with core.new_main(JaxprTrace) as main:
#     509     fun = trace_to_subjaxpr(fun, main, instantiate)
# --> 510     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     511     assert not env
#     512     del main, fun, env
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/projects/nn_ansatz/src/nn_ansatz/vmc.py in _grad_function(params, walkers, d0s)
#      31     def _grad_function(params, walkers, d0s):
#      32
# ---> 33         e_locs = lax.stop_gradient(compute_energy(params, walkers, d0s))
#      34         e_locs_centered = clip_and_center(e_locs)
#      35         log_psi = vwf(params, walkers, d0s)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     380         return cpp_jitted_f(*args, **kwargs)
#     381       else:
# --> 382         return cpp_jitted_f(context, *args, **kwargs)
#     383   else:
#     384     cpp_jitted_f = jax_jit.jit(fun, cache_miss, get_device_info,
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in cache_miss_wrapper(_, *args, **kw)
#     349   # version.
#     350   if lib._xla_extension_version < 11:
# --> 351     def cache_miss_wrapper(_, *args, **kw): return cache_miss(*args, **kw)
#     352     static_argnums_ = (0,) + tuple(i + 1 for i in static_argnums)
#     353     cpp_jitted_f = jax_jit.jit(fun, cache_miss_wrapper, get_device_info,
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in cache_miss(*args, **kwargs)
#     293       _check_arg(arg)
#     294     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 295     out_flat = xla.xla_call(
#     296         flat_fun,
#     297         *args_flat,
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/ad.py in process_call(self, call_primitive, f, tracers, params)
#     317     update_params = call_param_updaters.get(call_primitive)
#     318     new_params = update_params(params, nz_tangents) if update_params else params
# --> 319     result = call_primitive.bind(f_jvp, *primals, *nonzero_tangents, **new_params)
#     320     primal_out, tangent_out = tree_unflatten(out_tree_def(), result)
#     321     return [JVPTracer(self, p, t) for p, t in zip(primal_out, tangent_out)]
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, primitive, f, tracers, params)
#     194       app = partial(primitive.bind, **params)
#     195     with ctx:
# --> 196       jaxpr, out_pvals, consts, env_tracers = self.partial_eval(
#     197           f, in_pvals, app, instantiate=False)
#     198       if primitive.map_primitive:
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in partial_eval(self, f, pvals, app, instantiate)
#     302     f = trace_to_subjaxpr(f, self.main, instantiate)
#     303     f, aux = partial_eval_wrapper(f, tuple(in_avals))
# --> 304     out_flat, (out_avals, jaxpr, env) = app(f, *in_consts), aux()
#     305     out_consts, consts = split_list(out_flat, [len(out_flat)-len(jaxpr.constvars)])
#     306     out_pvs = map(PartialVal, zip(out_avals, out_consts))
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1400
#    1401   def bind(self, fun, *args, **params):
# -> 1402     return call_bind(self, fun, *args, **params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1391   tracers = map(top_trace.full_raise, args)
#    1392   with maybe_new_sublevel(top_trace):
# -> 1393     outs = primitive.process(top_trace, fun, tracers, params)
#    1394   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1395
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1403
#    1404   def process(self, trace, fun, tracers, params):
# -> 1405     return trace.process_call(self, fun, tracers, params)
#    1406
#    1407   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_call(self, call_primitive, f, tracers, params)
#    1080   def process_call(self, call_primitive, f, tracers, params):
#    1081     in_avals = [t.aval for t in tracers]
# -> 1082     jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(f, self.main, in_avals)
#    1083     if not jaxpr.eqns:
#    1084       return core.eval_jaxpr(jaxpr, consts, *tracers)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr_dynamic(fun, main, in_avals)
#    1206     trace = DynamicJaxprTrace(main, core.cur_sublevel())
#    1207     in_tracers = map(trace.new_arg, in_avals)
# -> 1208     ans = fun.call_wrapped(*in_tracers)
#    1209     out_tracers = map(trace.full_raise, ans)
#    1210     jaxpr, out_avals, consts = frame.to_jaxpr(in_tracers, out_tracers)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/projects/nn_ansatz/src/nn_ansatz/vmc.py in _compute_local_energy(params, walkers, d0s)
#      52
#      53     def _compute_local_energy(params, walkers, d0s):
# ---> 54         potential_energy = compute_potential_energy(walkers, r_atoms, z_atoms)
#      55         kinetic_energy = local_kinetic_energy(params, walkers, d0s)
#      56         return potential_energy + kinetic_energy
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/api.py in batched_fun(*args, **kwargs)
#    1227     in_axes_flat = flatten_axes("vmap in_axes", in_tree, (in_axes, 0), kws=True)
#    1228     axis_size = _mapped_axis_size(in_tree, args_flat, in_axes_flat, "vmap", kws=True)
# -> 1229     out_flat = batching.batch(
#    1230         flat_fun, axis_name, axis_size, in_axes_flat,
#    1231         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# ~/projects/nn_ansatz/src/nn_ansatz/vmc.py in compute_potential_energy_solid_i(walkers, r_atoms, z_atoms)
#      96
#      97             a_e_dist = batched_cdist_l2(ex_r_atoms, walkers)
# ---> 98             potential_energy -= jnp.sum(ex_z_atoms / a_e_dist)
#      99
#     100             a_a_dist = batched_cdist_l2(r_atoms, ex_r_atoms)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in __truediv__(self, other)
#     502   def __div__(self, other): return self.aval._div(self, other)
#     503   def __rdiv__(self, other): return self.aval._rdiv(self, other)
# --> 504   def __truediv__(self, other): return self.aval._truediv(self, other)
#     505   def __rtruediv__(self, other): return self.aval._rtruediv(self, other)
#     506   def __floordiv__(self, other): return self.aval._floordiv(self, other)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    5331     if not isinstance(other, _scalar_types + _arraylike_types + (core.Tracer,)):
#    5332       return NotImplemented
# -> 5333     return binary_op(self, other)
#    5334   return deferring_binary_op
#    5335
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in true_divide(x1, x2)
#     536 def true_divide(x1, x2):
#     537   x1, x2 = _promote_args_inexact("true_divide", x1, x2)
# --> 538   return lax.div(x1, x2)
#     539
#     540 divide = true_divide
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/lax/lax.py in div(x, y)
#     354 def div(x: Array, y: Array) -> Array:
#     355   r"""Elementwise division: :math:`x \over y`."""
# --> 356   return div_p.bind(x, y)
#     357
#     358 def rem(x: Array, y: Array) -> Array:
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in bind(self, *args, **params)
#     257     top_trace = find_top_trace(args)
#     258     tracers = map(top_trace.full_raise, args)
# --> 259     out = top_trace.process_primitive(self, tracers, params)
#     260     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     261
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/batching.py in process_primitive(self, primitive, tracers, params)
#     152     else:
#     153       batched_primitive = get_primitive_batcher(primitive, self.axis_name)
# --> 154       val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     155     if primitive.multiple_results:
#     156       return map(partial(BatchTracer, self), val_out, dim_out)
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/batching.py in broadcast_batcher(prim, args, dims, **params)
#     336     ndim = max(np.ndim(x) for x in args)  # special-case scalar broadcasting
#     337     args = [_handle_scalar_broadcasting(ndim, x, d) for x, d in zip(args, dims)]
# --> 338     out = prim.bind(*args, **params)
#     339     return (out, (0,) * len(out)) if prim.multiple_results else (out, 0)
#     340
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/core.py in bind(self, *args, **params)
#     257     top_trace = find_top_trace(args)
#     258     tracers = map(top_trace.full_raise, args)
# --> 259     out = top_trace.process_primitive(self, tracers, params)
#     260     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     261
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/interpreters/partial_eval.py in process_primitive(self, primitive, tracers, params)
#    1068   def process_primitive(self, primitive, tracers, params):
#    1069     avals = [t.aval for t in tracers]
# -> 1070     out_avals = primitive.abstract_eval(*avals, **params)
#    1071     out_avals = [out_avals] if not primitive.multiple_results else out_avals
#    1072     source_info = source_info_util.current()
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/lax/lax.py in standard_abstract_eval(prim, shape_rule, dtype_rule, weak_type_rule, named_shape_rule, *avals, **kwargs)
#    2008                          weak_type=weak_type)
#    2009   elif least_specialized is ShapedArray:
# -> 2010     return ShapedArray(shape_rule(*avals, **kwargs), dtype_rule(*avals, **kwargs),
#    2011                        weak_type=weak_type,
#    2012                        named_shape=named_shape_rule(*avals, **kwargs))
#
# ~/anaconda3/envs/xmax/lib/python3.8/site-packages/jax/_src/lax/lax.py in _broadcasting_shape_rule(name, *avals)
#    2104   if result_shape is None:
#    2105     msg = '{} got incompatible shapes for broadcasting: {}.'
# -> 2106     raise TypeError(msg.format(name, ', '.join(map(str, map(tuple, shapes)))))
#    2107   return result_shape
#    2108
#
# TypeError: div got incompatible shapes for broadcasting: (2048, 3, 3), (2048, 3, 14).
